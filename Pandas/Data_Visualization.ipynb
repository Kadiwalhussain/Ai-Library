# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.linspace(0, 20)
plt.plot(a, a + 0.5, label='linear')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

days = np.arange(1,8)
product_a_sales = np.array([200, 234,533,232,544,646,564])
product_b_sales = np.array([334,535,464,646,677,886,443])

plt.figure(figsize = (8,5))
plt.plot(days, product_a_sales, label = 'Product A', color='blue', marker = 'o')
plt.plot(days, product_b_sales , label = 'Product B', color = 'red', marker = 's')
plt.xlabel('Day')
plt.ylabel('Sales')
plt.title('Daily Sales for two product')
plt.legend()
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
x = [1, 3, 5, 7, 9, 11]
y = [10, 25, 35, 33, 41, 59]
plt.plot(x, y, label='Series-1', color='blue')
x = [2, 4, 6, 8, 10, 12]
y = [15, 29, 32, 33, 38, 55]
plt.plot(x, y, label='Series-2', color='red')
plt.xlabel("X-label")
plt.ylabel("Y-label")
plt.title("Multiple Python Line Graph")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 3, 5, 7, 9, 11]
y = [10, 25, 35, 33, 41, 59]
plt.scatter(x, y, c='blue', marker='*', alpha=0.5)
plt.xlabel("X-label")
plt.ylabel("Y-label")
plt.title("Scatter Chart Sample")
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 3, 5, 7, 9, 11]
y = [10, 25, 35, 33, 41, 59]
plt.plot(x, y)
plt.xlabel("X-label")
plt.ylabel("Y-label")
plt.title("Line Chart Sample")
plt.show()

# %%
import matplotlib.pyplot as plt
subjects = ["Mathematics", "Science", "Communication Skills", "Computer Application"]
scores = [85, 62, 57, 92]
plt.pie(scores, labels=subjects, colors=['r', 'g', 'b', 'y'], startangle=90,
        shadow=True, explode=(0, 0.1, 0, 0), autopct='%1.1f%%')
plt.title("Student Performance")
plt.show()

# %%
import matplotlib.pyplot as plt
movie_ratings = [1, 2, 3, 4, 5]
rating_counts = [21, 45, 72, 89, 42]
plt.bar(movie_ratings, rating_counts, color='blue')
plt.xlabel("Movie Ratings")
plt.ylabel("Rating Frequency")
plt.title("Movie Rating Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(8, 5))
countries = ['Qatar', 'Luxembourg', 'Singapore', 'Brunei', 'Ireland', 'Norway', 'UAE', 'Kuwait']
populations = [2781682, 604245, 5757499, 428963, 4818690, 5337962, 9630959, 4137312]
gdp_per_capita = [130475, 106705, 100345, 79530, 78785, 74356, 69382, 67000]
scaled_gdp_per_capita = np.divide(gdp_per_capita, 80)
colors = np.random.rand(8)
plt.scatter(countries, populations, s=scaled_gdp_per_capita, c=colors, cmap="Blues", edgecolors="grey", alpha=0.5)
plt.xlabel("Countries")
plt.ylabel("Population")
plt.title("Bubble Chart")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({
    'name': ['Ajay', 'Malala', 'Abhijeet', 'Yming', 'Desilva', 'Lisa'],
    'age': [22, 72, 25, 19, 42, 38],
    'gender': ['M', 'F', 'M', 'M', 'M', 'F'],
    'country': ['India', 'Pakistan', 'Bangladesh', 'China', 'Srilanka', 'UK'],
    'income': [2500, 3800, 3300, 2100, 4500, 5500]
})
df.plot(kind='scatter', x='age', y='income', color='red', title='Age Vs Income')
plt.show()

# %%
pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load a sample dataset (e.g., telecom churn)
df = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/telecom_churn.csv")

# Basic EDA
print(df.head())
print(df.isna().sum())  # Check for missing values

# lmplot: MonthlyCharges vs. Tenure, colored by Churn
sns.lmplot(x='tenure', y='MonthlyCharges', data=df, hue='Churn', fit_reg=True, ci=None)
plt.title("Customer Tenure vs. Monthly Charges by Churn Status")
plt.show()

# Alternative: No regression line
sns.lmplot(x='tenure', y='MonthlyCharges', data=df, hue='Churn', fit_reg=False)
plt.title("Customer Tenure vs. Monthly Charges (No Regression)")
plt.show()
# Out:
# An error occurred: HTTP Error 404: Not Found

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample e-commerce dataset
df = pd.DataFrame({
    'category': ['Electronics', 'Clothing', 'Books', 'Electronics', 'Clothing', 'Books'],
    'sales': [1000, 500, 200, 1200, 600, 300]
})

# Barplot: Average sales per category
sns.barplot(x='category', y='sales', data=df, estimator='mean', ci=None)
plt.title("Average Sales by Product Category")
plt.show()

# With hue (e.g., by region)
df['region'] = ['North', 'South', 'North', 'South', 'North', 'South']
sns.barplot(x='category', y='sales', hue='region', data=df, estimator='mean')
plt.title("Average Sales by Category and Region")
plt.show()
# Out:
# /tmp/ipython-input-19-3813433302.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='category', y='sales', data=df, estimator='mean', ci=None)

# %%
# Import the required modules
from bokeh.plotting import figure
from bokeh.plotting import output_notebook
from bokeh.plotting import show

# Create the data
x = [1, 3, 5, 7, 9, 11]
y = [10, 25, 35, 33, 41, 59]

# Output to notebook
output_notebook()

# Instantiate a figure
fig = figure(width=500, height=350)

# Create scatter circle marker plot by rendering the circles
fig.scatter(x, y, size=10, color="red", alpha=0.7)

# Show the plot
show(fig)
# Out:
#   <div id="f7a7772f-7941-475d-8ffd-388601899563" data-root-id="p1092" style="display: contents;"></div>

# %%
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Create a ColumnDataSource for better data handling
source = ColumnDataSource(df)

# Instantiate a figure with title and labels
fig = figure(width=500, height=350, title="Iris Dataset: Petal Length vs. Sepal Length",
             x_axis_label="Petal Length", y_axis_label="Sepal Length",
             tools="pan,box_zoom,reset,save")

# Add scatter plot with different colors per species
colors = {"setosa": "green", "versicolor": "blue", "virginica": "red"}
for species in df["species"].unique():
    species_data = df[df["species"] == species]
    fig.circle("petal_length", "sepal_length", size=8, color=colors[species], alpha=0.7,
               legend_label=species, source=ColumnDataSource(species_data))

# Add hover tool for interactivity
hover = HoverTool(tooltips=[
    ("Species", "@species"),
    ("Petal Length", "@petal_length"),
    ("Sepal Length", "@sepal_length")
])
fig.add_tools(hover)

# Customize legend
fig.legend.click_policy = "hide"  # Click to hide/show glyphs
fig.legend.location = "top_left"

# Show the plot
show(fig)
# Out:
# ...
#   <div id="bec203e3-7353-4ea5-922f-dcf7f79646e3" data-root-id="p1236" style="display: contents;"></div>

# %%
pip install bokeh_sampledata
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.3/242.3 kB 17.9 MB/s eta 0:00:00
# ...

# %%
from bokeh.plotting import figure, output_notebook, show

x_values = [1, 3, 5, 7, 9, 11]
y_values = [10, 25, 35, 33, 41, 59]

output_notebook()

p = figure(width=500, height=350)

p.line(x_values, y_values, line_width=1, color="blue")

show(p)
# Out:
#   <div id="d5e0dbdf-0952-4d85-a927-90a00defce98" data-root-id="p1328" style="display: contents;"></div>

# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource, HoverTool

# Create synthetic sales data
dates = pd.date_range("2025-01-01", "2025-01-10", freq="D")
sales = np.random.randint(100, 500, size=len(dates))
df = pd.DataFrame({"date": dates, "sales": sales})

# Output to notebook
output_notebook()

# Create ColumnDataSource
source = ColumnDataSource(df)

# Instantiate figure
fig = figure(width=600, height=400, title="Daily Sales (Jan 2025)",
             x_axis_type="datetime", x_axis_label="Date", y_axis_label="Sales ($)",
             tools="pan,box_zoom,reset,save")

# Add line plot
fig.line(x="date", y="sales", source=source, line_width=2, color="purple", legend_label="Sales")

# Add hover tool
hover = HoverTool(tooltips=[("Date", "@date{%F}"), ("Sales", "@sales")],
                        formatters={"@date": "datetime"})
fig.add_tools(hover)

# Show plot
show(fig)
# Out:
#   <div id="f71bae3b-4187-4c0a-bdd0-2f3de877f620" data-root-id="p1507" style="display: contents;"></div>

# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource


dates = pd.date_range("2025-01-01", "2025-01-10", freq = "D")
sales = np.random.randint(100, 500, size=len(dates))
df = pd.DataFrame({"Date": dates, "sales": sales})


output_notebook()

source = ColumnDataSource(df)

fig = figure(plot_width = 600, plot_height = 400, title = "Daily Sales(Jan 2025)",
             x_axis_type ="datetime", x_axis_label = "Date", y_axis_label = "Sales",
             tools = "pan, box_zoom, reset, save")


fig.line(x="date", y="sales", line_width=2, color="purple", legend_label = "Sales")


fig.add_tools(HoverTool(tooltips=[("Date", "@date{%F}"), ("Sales", "@sales")],
                        formatters={"@date": "datetime"}))


show(fig)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-37-3273934623.py in <cell line: 0>()
#      14 source = ColumnDataSource(df)
#      15
# ---> 16 fig = figure(plot_width = 600, plot_height = 400, title = "Daily Sales(Jan 2025)",
#      17              x_axis_type ="datetime", x_axis_label = "Date", y_axis_label = "Sales",
#      18              tools = "pan, box_zoom, reset, save")
#
# /usr/local/lib/python3.11/dist-packages/bokeh/plotting/_figure.py in __init__(self, *arg, **kw)
#     195         for name in kw.keys():
#     196             if name not in names:
# --> 197                 self._raise_attribute_error_with_matches(name, names | opts.properties())
#     198
#     199         super().__init__(*arg, **kw)
#
# /usr/local/lib/python3.11/dist-packages/bokeh/core/has_props.py in _raise_attribute_error_with_matches(self, name, properties)
# ...

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import row
from bokeh.sampledata.iris import flowers as df

output_notebook()

fig1 = figure(width=300, height=300)
fig2 = figure(width=300, height=300)
fig3 = figure(width=300, height=300)

fig1.circle(df['petal_length'], df['sepal_length'], size=8, color="green", alpha=0.5)
fig2.circle(df['petal_length'], df['sepal_width'], size=8, color="blue", alpha=0.5)
fig3.circle(df['petal_length'], df['petal_width'], size=8, color="red", alpha=0.5)

row_layout = row(fig1, fig2, fig3)

show(row_layout)
# Out:
# ...
#   <div id="c6577eb7-0aee-4cd6-ba2e-ce16e0fdc4db" data-root-id="p1707" style="display: contents;"></div>

# %%
from bokeh.layouts import gridplot

grid_layout = gridplot([[fig1, fig2], [None, fig3]])
show(grid_layout)
# Out:
#   <div id="a40c06b7-71c4-48b6-9bc7-7df7cfbe14e1" data-root-id="p1721" style="display: contents;"></div>

# %%
from bokeh.io import show
from bokeh.models import Button, SetValue

button = Button(label="Foo", button_type="primary")
callback = SetValue(obj=button, attr="label", value="Bar")
button.js_on_event("button_click", callback)

show(button)
# Out:
#   <div id="c50d531c-a751-402a-9fea-571b3037c107" data-root-id="p1729" style="display: contents;"></div>

# %%
from __future__ import annotations

import numpy as np

from bokeh import events
from bokeh.io import curdoc, show
from bokeh.layouts import column, row
from bokeh.models import Button, CustomJS, Div, TextInput
from bokeh.plotting import figure


def display_event(div: Div, attributes: list[str] = []) -> CustomJS:
    """
    Function to build a suitable CustomJS to display the current event
    in the div model.
    """
    style = 'float: left; clear: left; font-size: 13px'
    return CustomJS(args=dict(div=div), code=f"""
        const attrs = {attributes};
        const args = [];
        for (let i = 0; i < attrs.length; i++) {{
            const val = JSON.stringify(cb_obj[attrs[i]], function(key, val) {{
                return val.toFixed ? Number(val.toFixed(2)) : val;
            }})
            args.push(attrs[i] + '=' + val)
        }}
        const line = "<span style={style!r}><b>" + cb_obj.event_name + "</b>(" + args.join(", ") + ")</span>\\n";
        const text = div.text.concat(line);
        const lines = text.split("\\n")
        if (lines.length > 35)
            lines.shift();
        div.text = lines.join("\\n");
    """)

N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = np.array([(r, g, 150) for r, g in zip(50+2*x, 30+2*y)], dtype="uint8")

p = figure(tools="pan,wheel_zoom,zoom_in,zoom_out,reset,tap,lasso_select,box_select,box_zoom,undo,redo")

p.circle(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# Add a div to display events and a button to trigger button click events

div = Div(width=1000)
button = Button(label="Button", button_type="success", width=300)
text_input = TextInput(placeholder="Input a value and press Enter ...", width=300)
layout = column(button, text_input, row(p, div))

# Register event callbacks

# Button events
button.js_on_event(events.ButtonClick, display_event(div))

# TextInput events
text_input.js_on_event(events.ValueSubmit, display_event(div, ["value"]))

# AxisClick events
p.xaxis[0].js_on_event(events.AxisClick, display_event(div, ["value"]))
p.yaxis[0].js_on_event(events.AxisClick, display_event(div, ["value"]))

# LOD events
p.js_on_event(events.LODStart, display_event(div))
p.js_on_event(events.LODEnd, display_event(div))

# Point events
point_attributes = ['x','y','sx','sy']
p.js_on_event(events.Tap,       display_event(div, attributes=point_attributes))
p.js_on_event(events.DoubleTap, display_event(div, attributes=point_attributes))
p.js_on_event(events.Press,     display_event(div, attributes=point_attributes))
p.js_on_event(events.PressUp,   display_event(div, attributes=point_attributes))

# Mouse wheel event
p.js_on_event(events.MouseWheel, display_event(div,attributes=[*point_attributes, 'delta']))

# Mouse move, enter and leave
# p.js_on_event(events.MouseMove,  display_event(div, attributes=point_attributes))
p.js_on_event(events.MouseEnter, display_event(div, attributes=point_attributes))
p.js_on_event(events.MouseLeave, display_event(div, attributes=point_attributes))

# Pan events
pan_attributes = [*point_attributes, 'delta_x', 'delta_y']
p.js_on_event(events.Pan,      display_event(div, attributes=pan_attributes))
p.js_on_event(events.PanStart, display_event(div, attributes=point_attributes))
p.js_on_event(events.PanEnd,   display_event(div, attributes=point_attributes))

# Pinch events
pinch_attributes = [*point_attributes, 'scale']
p.js_on_event(events.Pinch,      display_event(div, attributes=pinch_attributes))
p.js_on_event(events.PinchStart, display_event(div, attributes=point_attributes))
p.js_on_event(events.PinchEnd,   display_event(div, attributes=point_attributes))

# Ranges Update events
p.js_on_event(events.RangesUpdate, display_event(div, attributes=['x0','x1','y0','y1']))

# Selection events
p.js_on_event(events.SelectionGeometry, display_event(div, attributes=['geometry', 'final']))

curdoc().on_event(events.DocumentReady, display_event(div))

show(layout)
# Out:
#   <div id="e21c1e7a-14ed-48a8-b38c-5fb132472cd2" data-root-id="p1791" style="display: contents;"></div>

# %%
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import row, column
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Create figures
fig1 = figure(width=400, height=300, title="Petal Length vs. Sepal Length",
              x_axis_label="Petal Length", y_axis_label="Sepal Length",
              tools="pan,box_zoom,reset,save")
fig2 = figure(width=400, height=300, title="Petal Length vs. Sepal Width",
              x_axis_label="Petal Length", y_axis_label="Sepal Width")
fig3 = figure(width=400, height=300, title="Petal Length vs. Petal Width",
              x_axis_label="Petal Length", y_axis_label="Petal Width")

# Add scatter plots
colors = {"setosa": "green", "versicolor": "blue", "virginica": "red"}
for species in df["species"].unique():
    species_data = df[df["species"] == species]
    color = colors[species]
    source = ColumnDataSource(species_data) # Create ColumnDataSource for each species
    fig1.scatter("petal_length", "sepal_length", size=8, color=color, alpha=0.5,
                legend_label=species, source=source) # Use the species-specific source
    fig2.scatter("petal_length", "sepal_width", size=8, color=color, alpha=0.5,
                legend_label=species, source=source) # Use the species-specific source
    fig3.scatter("petal_length", "petal_width", size=8, color=color, alpha=0.5,
                legend_label=species, source=source) # Use the species-specific source

# Add hover tools
hover = HoverTool(tooltips=[("Species", "@species"), ("Petal Length", "@petal_length"),
                            ("Sepal Length", "@sepal_length")])
fig1.add_tools(hover)
fig2.add_tools(hover)
fig3.add_tools(hover)

# Create nested layout
layout = row(fig1, column(fig2, fig3))

# Show plot
show(layout)
# Out:
#   <div id="b0a03396-9aac-4004-8f5f-76f2b44c55b4" data-root-id="p2243" style="display: contents;"></div>

# %%
# Import the required modules
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import CategoricalColorMapper, ColumnDataSource
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Instantiate a figure object
fig = figure(width=500, height=350, title="Petal length Vs. Petal Width",
             x_axis_label='petal_length', y_axis_label='petal_width')

# Create scatter marker plot by rendering circles
for specie, color in zip(['setosa', 'virginica', 'versicolor'], ['blue', 'green', 'red']):
    data = df[df.species == specie]
    source = ColumnDataSource(data)
    fig.circle('petal_length', 'petal_width', size=8, color=color, alpha=0.7,
               legend_label=specie, source=source)

# Set the legend location and click policy
fig.legend.location = 'top_left'
fig.legend.click_policy = "hide"

# Show the plot
show(fig)
# Out:
#   <div id="c3ee90d0-5722-438a-ba90-202225fc8098" data-root-id="p2442" style="display: contents;"></div>

# %%
# Import the required modules
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import CategoricalColorMapper, ColumnDataSource
from bokeh.sampledata.iris import flowers as df

# Output to notebook
output_notebook()

# Instantiate a figure object
fig = figure(width=500, height=350, title="Petal length Vs. Petal Width",
             x_axis_label='petal_length', y_axis_label='petal_width')

# Create scatter marker plot by rendering circles
for specie, color in zip(['setosa', 'virginica', 'versicolor'], ['blue', 'green', 'red']):
    data = df[df.species == specie]
    source = ColumnDataSource(data)
    fig.scatter('petal_length', 'petal_width', size=8, color=color, alpha=0.7,
               legend_label=specie, source=source)

# Set the legend location and click policy
fig.legend.location = 'top_left'
fig.legend.click_policy = "hide"

# Show the plot
show(fig)
# Out:
#   <div id="fec7bf75-b430-4bf3-bca0-d1f2d96ef346" data-root-id="p2535" style="display: contents;"></div>

# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource

# Sample churn data
data = {
    'churn': ['Yes']*50 + ['No']*50,
    'tenure': np.random.uniform(1, 72, 100),
    'monthly_charges': np.random.uniform(20, 120, 100)
}
df = pd.DataFrame(data)

output_notebook()
fig = figure(width=600, height=400, title="Tenure vs. Monthly Charges by Churn",
             x_axis_label='Tenure (months)', y_axis_label='Monthly Charges ($)')

for churn, color in zip(['Yes', 'No'], ['red', 'blue']):
    data = df[df.churn == churn]
    source = ColumnDataSource(data) # Create ColumnDataSource for each churn category
    fig.scatter('tenure', 'monthly_charges', size=8, color=color, alpha=0.7,
               legend_label=churn, source=source, muted_color='gray', muted_alpha=0.1)

fig.legend.location = 'top_left'
fig.legend.click_policy = 'mute'
show(fig)
# Out:
#   <div id="dffa6dc8-3e29-4d94-aac2-04a0c3dcd058" data-root-id="p2628" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import CategoricalColorMapper, ColumnDataSource
from bokeh.sampledata.iris import flowers as df

output_notebook()
color_mapper = CategoricalColorMapper(factors=['setosa', 'virginica', 'versicolor'],
                                     palette=['blue', 'green', 'red'])
color_dict = {'field': 'species', 'transform': color_mapper}

source = ColumnDataSource(df) # Create ColumnDataSource

p = figure(width=500, height=350, title="Petal length Vs. Petal Width",
           x_axis_label='petal_length', y_axis_label='petal_width')

p.scatter('petal_length', 'petal_width', size=8, color=color_dict, alpha=0.5,
         legend_group='species', source=source) # Use scatter and source

p.legend.location = 'top_left'
show(p)
# Out:
#   <div id="ed1357ef-c75b-4da1-a64b-48c1ef3af8bc" data-root-id="p2704" style="display: contents;"></div>

# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import CategoricalColorMapper, ColumnDataSource

data = {
    'region': ['North', 'South', 'East', 'West']*25,
    'sales': np.random.uniform(100, 1000, 100),
    'profit': np.random.uniform(10, 200, 100)
}
df = pd.DataFrame(data)

output_notebook()
color_mapper = CategoricalColorMapper(factors=['North', 'South', 'East', 'West'],
                                     palette=['blue', 'green', 'red', 'orange'])
color_dict = {'field': 'region', 'transform': color_mapper}

source = ColumnDataSource(df)

p = figure(width=600, height=400, title="Sales vs. Profit by Region",
           x_axis_label='Sales ($)', y_axis_label='Profit ($)')

p.scatter('sales', 'profit', size=8, color=color_dict, alpha=0.5,
         legend_group='region', source=source)

p.legend.location = 'top_left'
show(p)
# Out:
#   <div id="e313adc1-7768-45b8-809f-2ea16f8de5e1" data-root-id="p2765" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import CategoricalColorMapper, HoverTool, ColumnDataSource
from bokeh.sampledata.iris import flowers as df

output_notebook()
mapper = CategoricalColorMapper(factors=['setosa', 'virginica', 'versicolor'],
                               palette=['blue', 'green', 'red'])
color_dict = {'field': 'species', 'transform': mapper}

hover = HoverTool(tooltips=[('Species type', '@species'),
                            ('IRIS Petal Length', '@petal_length'),
                            ('IRIS Petal Width', '@petal_width')])

source = ColumnDataSource(df)

p = figure(width=500, height=350, title="Petal length Vs. Petal Width",
           x_axis_label='petal_length', y_axis_label='petal_width',
           tools=[hover, 'pan', 'wheel_zoom'])

p.scatter('petal_length', 'petal_width', size=8, color=color_dict, alpha=0.5,
         legend_group='species', source=source)

p.legend.location = 'top_left'
show(p)
# Out:
#   <div id="c4215308-3ae9-4fba-b606-88428c3dd629" data-root-id="p2874" style="display: contents;"></div>

# %%
# Import the required modules
from bokeh.plotting import figure
from bokeh.plotting import output_notebook
from bokeh.plotting import show
from bokeh.models import Tabs, Panel, ColumnDataSource # Import Tabs and Panel directly from bokeh.models
# Import iris flower dataset as pandas DataFrame
from bokeh.sampledata.iris import flowers as df
# Output to notebook
output_notebook()
# Instantiate figures
fig1 = figure(width=300, height=300) # Use width and height
fig2 = figure(width=300, height=300) # Use width and height
# Create scatter marker plot by render the circles
source = ColumnDataSource(df) # Create ColumnDataSource
fig1.scatter('petal_length', 'sepal_length', size=8, color="green", alpha=0.5, source=source) # Use scatter
fig2.scatter('petal_length', 'sepal_width', size=8, color="blue", alpha=0.5, source=source) # Use scatter
# Create panels
tab1 = Panel(elements=[fig1])
tab2 = Panel(elements=[fig2])
# Create tab by putting panels into it
tab_layout = Tabs(tabs=[(tab1, 'tab1'), (tab2, 'tab2')]) # Add titles here
# Show the plot
show(tab_layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-66-3979016803.py in <cell line: 0>()
#      19 tab2 = Panel(elements=[fig2])
#      20 # Create tab by putting panels into it
# ---> 21 tab_layout = Tabs(tabs=[(tab1, 'tab1'), (tab2, 'tab2')]) # Add titles here
#      22 # Show the plot
#      23 show(tab_layout)
#
# /usr/local/lib/python3.11/dist-packages/bokeh/models/layouts.py in __init__(self, *args, **kwargs)
#     580     # explicit __init__ to support Init signatures
#     581     def __init__(self, *args: Any, **kwargs: Any) -> None:
# --> 582         super().__init__(*args, **kwargs)
#     583
#     584     __example__ = "examples/interaction/widgets/tab_panes.py"
#
# /usr/local/lib/python3.11/dist-packages/bokeh/models/layouts.py in __init__(self, *args, **kwargs)
#     103     # explicit __init__ to support Init signatures
# ...

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import CustomJS, ColumnDataSource, Slider
from bokeh.layouts import column

output_notebook()

x = [x for x in range(0, 100)]
y = x

df = ColumnDataSource(data={"x_values": x, "y_values": y})

fig = figure(plot_width=350, plot_height=350)
fig.line('x_values', 'y_values', source=df, line_width=2.5, line_alpha=0.8)

callback = CustomJS(args=dict(source=df), code="""
    var data = source.data;
    var f = cb_obj.value;
    var x_values = data['x_values'];
    var y_values = data['y_values'];
    for (var i = 0; i < x_values.length; i++) {
        y_values[i] = Math.pow(x_values[i], f);
    }
    source.change.emit();
""")

slider_widget = Slider(start=0.0, end=10, value=1, step=0.1, title="Display power of x")
slider_widget.js_on_change('value', callback)

slider_widget_layout = column(fig, slider_widget)

show(slider_widget_layout)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-72-1693643304.py in <cell line: 0>()
#      10 df = ColumnDataSource(data={"x_values": x, "y_values": y})
#      11
# ---> 12 fig = figure(plot_width=350, plot_height=350)
#      13 fig.line('x_values', 'y_values', source=df, line_width=2.5, line_alpha=0.8)
#      14
#
# /usr/local/lib/python3.11/dist-packages/bokeh/plotting/_figure.py in __init__(self, *arg, **kw)
#     195         for name in kw.keys():
#     196             if name not in names:
# --> 197                 self._raise_attribute_error_with_matches(name, names | opts.properties())
#     198
#     199         super().__init__(*arg, **kw)
#
# /usr/local/lib/python3.11/dist-packages/bokeh/core/has_props.py in _raise_attribute_error_with_matches(self, name, properties)
#     375             matches, text = sorted(properties), "possible"
#     376
# ...

# %%
pip install bokeh

# %%
pip install notebook
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 8.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource, Slider, CustomJS, Tabs, Panel
from bokeh.layouts import column

# Output to notebook
output_notebook()

# Create synthetic sales data
np.random.seed(42)
months = [f"Month-{i}" for i in range(1, 13)]
regions = ['North', 'South', 'East']
data = {
    'month': months * len(regions),
    'region': np.repeat(regions, len(months)),
    'sales': np.random.randint(1000, 5000, size=len(months) * len(regions))
}
df = pd.DataFrame(data)

# Create ColumnDataSource for each region
sources = {}
js_sources = {}  # For JS callback args

for region in regions:
    region_data = df[df['region'] == region]
    source = ColumnDataSource(data={
        'month': region_data['month'],
        'sales': region_data['sales'],
        'scaled_sales': region_data['sales']
    })
    sources[region] = source
    js_sources[region] = source  # add to JS args

# Create tabs and plots
tabs = []
for region in regions:
    fig = figure(x_range=months, plot_width=400, plot_height=300, title=f"Sales in {region}")
    fig.line('month', 'scaled_sales', source=sources[region], line_width=2, color='blue')
    fig.xaxis.major_label_orientation = np.pi / 4
    tab = Panel(child=fig, title=region)
    tabs.append(tab)

# CustomJS callback with explicit args
callback = CustomJS(args=js_sources, code="""
    var f = cb_obj.value;
"""+ "\n".join([
    f"""
    var data_{r} = {r}.data;
    for (var i = 0; i < data_{r}['sales'].length; i++) {{
        data_{r}['scaled_sales'][i] = data_{r}['sales'][i] * f;
    }}
    {r}.change.emit();
    """ for r in regions
]))

# Slider and layout
slider = Slider(start=0.5, end=2.0, value=1.0, step=0.1, title="Sales Growth Multiplier")
slider.js_on_change('value', callback)

layout = column(Tabs(tabs=tabs), slider)
show(layout)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-74-634734302.py in <cell line: 0>()
#      36 tabs = []
#      37 for region in regions:
# ---> 38     fig = figure(x_range=months, plot_width=400, plot_height=300, title=f"Sales in {region}")
#      39     fig.line('month', 'scaled_sales', source=sources[region], line_width=2, color='blue')
#      40     fig.xaxis.major_label_orientation = np.pi / 4
#
# /usr/local/lib/python3.11/dist-packages/bokeh/plotting/_figure.py in __init__(self, *arg, **kw)
#     195         for name in kw.keys():
#     196             if name not in names:
# --> 197                 self._raise_attribute_error_with_matches(name, names | opts.properties())
#     198
#     199         super().__init__(*arg, **kw)
#
# ...
